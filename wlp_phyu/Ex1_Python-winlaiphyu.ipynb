# %% [markdown]
# <a href="https://colab.research.google.com/github/Winlai16/MMDT_T-PY101_Batch03/blob/main/wlp_phyu/Ex1_Python-winlaiphyu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 30
# 30 usd is equivalent to 24.599999999999998 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
Feranhite = input('Enter the current temperature in Feranhite: ')
Celsius = (int(Feranhite) -32)*5/9
print("{} Feranhite is equivalent to {} Celsius".format(Feranhite,Celsius))
# Out:
# Enter the current temperature in Feranhite: 100
# 100 Feranhite is equivalent to 37.77777777777778 Celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
Apple_Qty = int(input('Enter the quantiy of apple: '))
Apple_Amt = float(input('Enter the price of apple: '))
Org_Qty = int(input('Enter the quantiy of Orange: '))
Org_Amt = float(input('Enter the price of Orange: '))
Mango_Qty = int(input('Enter the quantiy of Mango: '))
Mango_Amt = float(input('Enter the price of Mango: '))
Total_Cost = (Apple_Qty*Apple_Amt)+(Org_Qty*Org_Amt)+(Mango_Qty*Mango_Amt)
print("Total cost of fruits is {} MMK ".format(Total_Cost))
# Out:
# Enter the quantiy of apple: 4
# Enter the price of apple: 345.9
# Enter the quantiy of Orange: 5
# Enter the price of Orange: 500
# Enter the quantiy of Mango: 6
# Enter the price of Mango: 300
# Total cost of fruits is 5683.6 MMK

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
user_name = input('Enter the customer name')
print("Hello Welcome from Sweet Thai Restaurant: "+user_name)
# Out:
# Enter the customer nameBo Bo Aung
# Hello Welcome from Sweet Thai Restaurant: Bo Bo Aung

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,10)
print('A random number between 1 and 10: ', x)
y = randint(2,5)
print('A random number between 2 and 5: ', y)
a= x^y
print(a)
b= x**y
print(b)
# Out:
# A random number between 1 and 10:  6
# A random number between 2 and 5:  4
# 2
# 1296

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x = randint(1,10)
a= x*"Win Lai Phyu "
print(a)
# Out:
# Win Lai Phyu Win Lai Phyu Win Lai Phyu Win Lai Phyu Win Lai Phyu Win Lai Phyu Win Lai Phyu Win Lai Phyu

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x=int(input("Please enter the number: "))
y=int(input("Please enter the number: "))
result = abs(x - y) / (x + y)
print(result)
# Out:
# Please enter the number: 30
# Please enter the number: 70
# 0.4

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
seconds = int(input("Please enter the number of seconds"))
minutes = seconds//60
seconds_d = seconds %60
print("200 seconds is equilvants to {}  minutes {} seconds ".format(minutes,seconds_d))
# Out:
# Please enter the number of seconds200
# 200 seconds is equilvants to 3  minutes 20 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))
sine_value = math.sin(num)
print(sine_value)
cosine_value = math.cos(num)
print(cosine_value)
tangent_value = math.tan(num)
print(tangent_value)
# Out:
# Enter a number:30
# -0.9880316240928618
# 0.15425144988758405
# -6.405331196646276
