# %% [markdown]
# <a href="https://colab.research.google.com/github/Winlai16/MMDT_T-PY101_Batch03/blob/main/wlp_phyu/Ex4_Looping_winlaiphyu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
string = "A_Practical_Introduction_to_Python_Programming_Heinold"
idx = 0
while idx < len(string):
  print(string[idx])
  idx = idx+1
# Out:
# A
# _
# P
# r
# a
# c
# t
# i
# c
# a
# l
# _
# I
# n
# t
# r
# o
# d
# u
# c
# t
# i
# o
# n
# _
# t
# o
# _
# P
# y
# t
# h
# o
# n
# _
# P
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
# _
# H
# e
# i
# n
# o
# l
# d

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight = int(input("Enter your weight in kilograms : "))
while weight <= 0 :
  print("entry is invalid and try again ")
  weight = int(input("Enter your weight in kilograms : "))
print(weight * 2.20462 )

# After the loop, weight is valid (> 0)
pounds = weight * 2.20462
# Out:
# Enter your weight in kilograms : 90
# 198.4158

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
result = 0
a_count = 0
count = 0
while True:
    score = int(input("Enter score (negative to finish): "))
    if score < 0:
        break

    result += score
    count += 1

    if score >= 90:
        a_count += 1
    average = result / count
print(f"Number of A's: {a_count}")
print(f"Average: {average}")
# Out:
# Enter score (negative to finish): 98
# Enter score (negative to finish): 99
# Enter score (negative to finish): 87
# Enter score (negative to finish): 90
# Enter score (negative to finish): 50
# Enter score (negative to finish): 99
# Enter score (negative to finish): -1
# Number of A's: 4
# Average: 87.16666666666667

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = input("Enter a sting : ")
letter = input("Enter a letter: ")
for i in range(len(string)):
  if string[i] == letter:
    print(f"first occurrence of that letter is {i}")
  else:
    print(f"{letter} not found in the string")
# Out:
# Enter a sting : pytthon
# Enter a letter: t
# t not found in the string
# t not found in the string
# first occurrence of that letter is 2
# first occurrence of that letter is 3
# t not found in the string
# t not found in the string
# t not found in the string

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
lis =[1,1,0,0,0,1,0]
for i in range(len(lis)):
  if lis[i] == 0:
    lis[i] = 1
    print("Changed first zero at index {}".format(i))
    break
  else:
    print("Not found zero at index {}".format(i))
print(lis)
# Out:
# Not found zero at index 0
# Not found zero at index 1
# Changed first zero at index 2
# [1, 1, 1, 0, 0, 1, 0]
